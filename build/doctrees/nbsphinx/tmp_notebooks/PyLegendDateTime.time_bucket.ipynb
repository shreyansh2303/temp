# %%
import pylegend
frame = pylegend.samples.pandas_api.northwind_orders_frame()

# %%
frame["bucket"] = frame["Shipped Date"].first_hour_of_day().time_bucket(6, "HOURS")
frame[["Shipped Date", "bucket"]].head(3).to_pandas()
# Out:
#   Shipped Date                    bucket
# 0   1996-07-16 1996-07-16 00:00:00+00:00
# 1   1996-07-10 1996-07-10 00:00:00+00:00
# 2   1996-07-12 1996-07-12 00:00:00+00:00
