# %%
import pylegend
frame = pylegend.samples.pandas_api.northwind_orders_frame()

# %%
frame.filter(
    items=["Order Id"]
).cume_dist_legend_ext().head(5).to_pandas()
# Out:
#    Order Id
# 0  0.001205
# 1   0.00241
# 2  0.003614
# 3  0.004819
# 4  0.006024
