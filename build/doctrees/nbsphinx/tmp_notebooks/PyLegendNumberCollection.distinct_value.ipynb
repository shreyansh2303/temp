# %%
import pylegend
frame = pylegend.samples.pandas_api.northwind_orders_frame()

# %%
frame.groupby("Order Id")["Order Id"].aggregate(
    lambda x: x.distinct_value()
).to_pandas().head(3)
# Out:
#    Order Id  lambda_0(Order Id)
# 0     10248               10248
# 1     10249               10249
# 2     10250               10250
