# %%
import pylegend
orders = pylegend.samples.legendql_api.northwind_orders_frame()

# %%
# Right join example
# Rename duplicate columns to avoid conflicts
cols = ["Order Id", "Ship Name"]
renames = [("Order Id", "Right Order Id"), ("Ship Name", "Filtered Ship Name")]
filtered_info = orders.filter(
    lambda r: r["Order Id"] > 10300
).select(cols).rename(renames).head(10)
orders.head(5).right_join(
    filtered_info,
    lambda l, r: l["Order Id"] == r["Right Order Id"]
).to_pandas()
# Out:
#    Order Id Order Date Required Date Shipped Date Ship Name  Right Order Id  \
# 0      <NA>        NaT           NaT          NaT       NaN           10301
# 1      <NA>        NaT           NaT          NaT       NaN           10302
# 2      <NA>        NaT           NaT          NaT       NaN           10303
# 3      <NA>        NaT           NaT          NaT       NaN           10304
# 4      <NA>        NaT           NaT          NaT       NaN           10305
# 5      <NA>        NaT           NaT          NaT       NaN           10306
# 6      <NA>        NaT           NaT          NaT       NaN           10307
# 7      <NA>        NaT           NaT          NaT       NaN           10308
# 8      <NA>        NaT           NaT          NaT       NaN           10309
# 9      <NA>        NaT           NaT          NaT       NaN           10310
#
#                    Filtered Ship Name
# 0                   Die Wandernde Kuh
# 1                    Suprêmes délices
# 2                 Godos Cocina Típica
# 3                 Tortuga Restaurante
# 4              Old World Delicatessen
# 5                    Romero y tomillo
# 6            Lonesome Pine Restaurant
# 7  Ana Trujillo Emparedados y helados
# 8        Hungry Owl All-Night Grocers
# 9                      The Big Cheese
