# %%
import pylegend
frame = pylegend.samples.pandas_api.northwind_orders_frame()

# %%
frame.filter(
    items=["Order Id"]
).ntile_legend_ext(4).head(5).to_pandas()
# Out:
#    Order Id
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
